# %%
import torch

# %%
ckpt_path = "pretrained_models/last.pt"
device = 0

# %%
state_dict = torch.load(ckpt_path, map_location=f'cuda:{device}')

# %%
state_dict
# Out:
# {'pos_embed': tensor([[[ 0.0000,  0.0000,  0.0000,  ...,  1.0000,  1.0000,  1.0000],
#           [ 0.8415,  0.8241,  0.8064,  ...,  1.0000,  1.0000,  1.0000],
#           [ 0.9093,  0.9336,  0.9538,  ...,  1.0000,  1.0000,  1.0000],
#           ...,
#           [ 0.4202,  0.0245, -0.3633,  ...,  1.0000,  1.0000,  1.0000],
#           [ 0.9906,  0.8376,  0.5364,  ...,  1.0000,  1.0000,  1.0000],
#           [ 0.6503,  0.9246,  0.9978,  ...,  1.0000,  1.0000,  1.0000]]],
#         device='cuda:0'),
#  'x_embedder.proj.weight': tensor([[[[ 3.1512e-03,  1.1600e-03],
#            [ 2.2990e-03, -2.8487e-03]],
#
#           [[ 8.7599e-03,  7.4493e-03],
#            [ 4.0841e-03,  4.7790e-03]],
#
#           [[-5.2319e-03, -1.8815e-03],
#            [ 7.2402e-04,  4.6852e-03]],
#
#           [[-1.2630e-03, -2.6694e-03],
#            [ 1.8097e-03, -2.6206e-03]]],
#
#
#          [[[ 7.3870e-03, -1.1429e-02],
#            [ 5.6217e-03, -2.6848e-03]],
#
#           [[ 2.2304e-02,  5.2505e-03],
# ...
